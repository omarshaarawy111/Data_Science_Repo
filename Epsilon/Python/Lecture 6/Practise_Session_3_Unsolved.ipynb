# %% [markdown]
# # <center>Practical session 3</center>

# %% [markdown]
# # Session outlines
# - Error Execption
# - File handling
# - Functions
# - Lambda expression
# - Map, Filter, Reduce
# - Variable Scope

# %% [markdown]
# ### 1.0 Error handling
# 1. Syntax errors
# 2. Logical errors (Exceptions)
#    - IndexError:	When the wrong index of a list is retrieved.
#    - ImportError:	It occurs when an imported module is not found.
#    - KeyError:	    It occurs when the key of the dictionary is not found.
#    - NameError:	    It occurs when the variable is not defined.
#    - IOError:       It occurs when file can’t be opened
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 1.1 How to handle zero division error

# %%
# Answer here 
number_1=int(input("enter number 1 : "))
number_2=int(input("enter number 2 : "))
try:
    result=number_1/number_2
    print(result)
except ZeroDivisionError as z:
    print("canot be devided by zero")
# Out:
# enter number 1 : 1
# enter number 2 : 0
# canot be devided by zero

# %% [markdown]
# ### 2.0 File hanling
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 2.1 Open file write "I love python" .

# %%
import os
import shutil
# Answer here 
#with open('test.txt','w') as file :
#    file.write("I love Pyhton")
#with open('test.txt','r') as file :
#    print(file.read())
#os.rename("D:\\Work\\DS\\Epsilon\\Python\\Lectures\\Lecture 6\\Practise Session 3\\Codes\\test.txt","D:\\Work\\DS\\Epsilon\\Python\\Lectures\\Lecture 6\\Practise Session 3\\Codes\\test_1.txt")
#os.remove("D:\\Work\\DS\\Epsilon\\Python\\Lectures\\Lecture 6\\Practise Session 3\\Codes\\test_1.txt")   
#os.listdir("D:\\Work\\DS\\Epsilon\\Python\\Lectures\\Lecture 6\\Practise Session 3")
#shutil.copy("D:\\Work\\DS\\Epsilon\\Python\\Lectures\\Lecture 6\\Practise Session 3\\Codes\\test.txt","D:\Work\DS\Epsilon\Python\Lectures\Lecture 6\Practise Session 3\Content")
#shutil.move("D:\\Work\\DS\\Epsilon\\Python\\Lectures\\Lecture 6\\Practise Session 3\\Codes\\test.txt","D:\Work\DS\Epsilon\Python\Lectures\Lecture 6\Practise Session 3\Content")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9988\2130085620.py in <module>
#      11 #shutil.copy("D:\\Work\\DS\\Epsilon\\Python\\Lectures\\Lecture 6\\Practise Session 3\\Codes\\test.txt","D:\Work\DS\Epsilon\Python\Lectures\Lecture 6\Practise Session 3\Content")
#      12 #shutil.move("D:\\Work\\DS\\Epsilon\\Python\\Lectures\\Lecture 6\\Practise Session 3\\Codes\\test.txt","D:\Work\DS\Epsilon\Python\Lectures\Lecture 6\Practise Session 3\Content")
# ---> 13 shutil.rmtree("D:\Work\DS\Epsilon\Python\Lectures\Lecture 6\Practise Session 3\Content\test.txt")
#
# C:\ProgramData\Anaconda3\lib\shutil.py in rmtree(path, ignore_errors, onerror)
#     757             # can't continue even if onerror hook returns
#     758             return
# --> 759         return _rmtree_unsafe(path, onerror)
#     760
# ...

# %% [markdown]
# ### 3.0 Functions
# - User defined function
# - Bulit-in function
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 3.1 Write a Python function to multiply all the numbers in a list.

# %%
# Answer here

# %% [markdown]
# ##### 3.2 Write a Python function that checks whether a passed string is palindrome or not

# %%
# Answer here

# %% [markdown]
# ##### 3.3 Write a Python program to reverse a string.

# %%
# Answer here

# %% [markdown]
# ##### 3.4 https://codeforces.com/contest/791/problem/A

# %%
# Answer here 
def years(limak,bob):
    count = 0 
    while 1  :
        limak *= 3
        bob *= 2
        count += 1
        if (limak > bob ):
            break
    print("Limak will be bigger than bob afrer {} years".format(count))   
    
    
    
def take () :
    limak=int(input("enter limak weight : "))
    bob=int(input("enter bob weight : "))
    if limak <= bob and limak >= 1 and bob <= 10 :
        years(limak,bob)
    else :
        print("invalid condition")
        print()
        take()

take()
# Out:
# enter limak weight : 1
# enter bob weight : 2
# Limak will be bigger than bob afrer 2 years

# %% [markdown]
# 4.0 Built-in functions
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 4.1 map : function returns a map object(which is an iterator) of the results after applying the given function to each item of a given iterable

# %%
# Answer here

# %% [markdown]
# ##### 4.2 filter : method filters the given sequence with the help of a function that tests each element in the sequence to be true or not.

# %%
# Answer here

# %% [markdown]
# ##### 4.3 enumerate : adds a counter to an iterable and returns it in a form of enumerating object.

# %%
# Answer here

# %% [markdown]
# ##### 4.4 zip : which is an iterator of tuples where the first item in each passed iterator is paired together, and then the second item in each passed iterator are paired together

# %%
# Answer here

# %% [markdown]
# ### 5.0 Lambda expression
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 5.1 Write a Python program to triple all numbers of a given list of integers. Use Python map and lambda.

# %%
# Answer here

# %% [markdown]
# ##### 5.2 Write a Python program to remove zero values given a list of numbers. Use a filter function.

# %%
# Answer here 
lst=list(input("enter list :").split())
for i in range(len(lst)):
    lst[i]=int(lst[i])
print(list(filter(lambda x : x > 0,lst)))
# Out:
# enter list :11 2 3 0 -9
# [11, 2, 3]

# %% [markdown]
# ##### 5.3  Write a Python program to link between this 2 lists.
# 1. languages = ['Java', 'Python', 'JavaScript']
# 2. versions = [14, 3, 6]

# %% [markdown]
# ### 6.0 Variable Scope
# ![image.png](attachment:image.png)

# %%
# Explain here 
languages = ['Java', 'Python', 'JavaScript']
versions = [14, 3, 6]
print(list(zip(languages,versions)))
# Out:
# [('Java', 14), ('Python', 3), ('JavaScript', 6)]

# %% [markdown]
# <center style="font-size:25px" >Best of Luck 😃💜</center>
